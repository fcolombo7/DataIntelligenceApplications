# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
os.chdir('/content/drive/MyDrive/DataIntelligenceApplications/')

# %% [markdown]
# ---
# _Here now check the step3 and step4 with this new environment._

# %% [markdown]
# ### STEP#3

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

from environments.complete_environment import CompleteEnvironment
from data_generators.standard_generator import StandardDataGenerator
from learners.pricing.thompson_sampling import ThompsonSampling
from learners.pricing.ucb import UCB

# %%
src = 'src/basic007.json'

# %%
dg = StandardDataGenerator(filename=src)
margins = dg.get_margins()

# %%
print('\n', 15 * '-', 'SIMULATION PARAMS', '-' * 15)
T = 365
n_experiments = 8
print(f'Time horizon: {T} days')
print(f'Num. experiments: {n_experiments}')
# Out:
#  --------------- SIMULATION PARAMS ---------------
# Time horizon: 365 days
# Num. experiments: 8

# %%
selected_bid = 4

# %%
learners_to_test = [ThompsonSampling, UCB]
#learners_to_test = [UCB]
rewards_per_experiment = {}
for learner in learners_to_test:
    rewards_per_experiment[learner.LEARNER_NAME] = []

# %%
for e in range(n_experiments):
    print(f'running experiment {e + 1}/{n_experiments}...\n')
    test_instances = []
    for learner in learners_to_test:
        test_instances.append((learner(arm_values=margins),
                               CompleteEnvironment(src=src)))
    for t in range(T):
        for learner, env in test_instances:
            learner.next_day()
            past_arms = env.get_selected_arms_at_day(t - 30, keep=False, filter_purchases=True)
            _ = env.get_collected_user_features_at_day(t - 30, keep=False, filter_purchases=True) # past features not usefull here
            month_purchases = env.get_next_purchases_at_day(t, keep=False, filter_purchases=True)
            if month_purchases is not None:
                for arm, n_purchases in zip(past_arms, month_purchases):
                    learner.update_single_future_purchase(arm, n_purchases)
            pulled_arm = learner.pull_arm()
            daily_reward, _, _ = env.day_round(pulled_arm, selected_bid=selected_bid, fixed_adv=True)
            for outcome, cost in daily_reward:
                learner.update(pulled_arm, outcome, cost)
    for learner, _ in test_instances:
        learner.next_day()
        rewards_per_experiment[learner.LEARNER_NAME].append(learner.daily_collected_rewards)
# Out:
# running experiment 1/8...
#
# running experiment 2/8...
#
# running experiment 3/8...
#
# running experiment 4/8...
#
# running experiment 5/8...
#
# running experiment 6/8...
#
# running experiment 7/8...
#
# running experiment 8/8...

# %%
margins = dg.get_margins()
classes = dg.get_classes()
conversion_rates = dg.get_conversion_rates(mode='all')
future_purchases = dg.get_future_purchases(mode='all')
number_of_clicks = dg.get_daily_clicks(mode='all')

costs_per_click = dg.get_costs_per_click(mode='aggregate', bid=selected_bid)
fixed_cost = costs_per_click[selected_bid]
fixed_n_clicks = np.rint(dg.get_daily_clicks(mode='aggregate')[selected_bid]).astype(int)
fractions = dg.get_class_distributions(selected_bid)

temp = (margins * np.average(conversion_rates * (1 + future_purchases),
                             axis=0,
                             weights=fractions) - fixed_cost) * fixed_n_clicks
aggr_opt_arm = np.argmax(temp)
aggr_opt = np.max(temp)

disaggr_opt = 0
opt_arms = []
disaggr_costs = dg.get_costs_per_click(mode='all')
for i, _ in enumerate(conversion_rates):
    t = (margins * conversion_rates[i] * (1 + future_purchases[i]) - disaggr_costs[i, selected_bid]) * \
                number_of_clicks[i, selected_bid]
    opt_arm = np.argmax(t)
    opt_value = np.max(t)
    opt_arms.append(opt_arm)
    disaggr_opt += opt_value

# %%
# Plotting the results
plt.figure(figsize=(10,8))
plt.ylabel("Regret")
plt.xlabel("day")
plt.plot(3500*np.sqrt(np.linspace(0,364,365)), '--')
for val in rewards_per_experiment.values():
    plt.plot(np.cumsum(np.mean(aggr_opt - val, axis=0)))

#plt.axvline(x=cg_start_from, color='r', linestyle='--')
#for val in days_of_split.values():
#    avg_days = np.mean(val, axis=0)
#    for day in avg_days:
#        plt.axvline(x=day, color='m', linestyle='--')

plt.legend(['O(sqrt-T)']+list(rewards_per_experiment.keys()))
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.xlabel("day")
plt.ylabel("daily reward")
plt.plot([disaggr_opt]*T, '--g', label='clairwoyant')
plt.plot([aggr_opt]*T, '--c', label='aggr_clairwoyant')
for key in rewards_per_experiment:
    plt.plot(np.mean(rewards_per_experiment[key], axis=0), label=key)

plt.legend(loc='best')
plt.show()

# %% [markdown]
# ---
# ### STEP#4

# %%
from learners.pricing.contextual_learner import ContextualLearner
from utils.context_generator import ContextGenerator

# %%
selected_bid = 4
T = 365
n_experiments = 8
learners_to_test = [ThompsonSampling, UCB]
cg_start_from = 60
cg_confidence = 0.02
cg_frequency = 10

features = dg.get_features() 
fractions = dg.get_class_distributions(selected_bid)
bandit_args = {
            'arm_values': dg.get_margins()
}

# %%
rewards_per_experiment = {}
context_split_per_experiment = {}
days_of_split = {}
for learner in learners_to_test:
    rewards_per_experiment[learner.LEARNER_NAME] = []
    context_split_per_experiment[learner.LEARNER_NAME] = []
    days_of_split[learner.LEARNER_NAME] = []

# %%
for e in range(n_experiments):
    # Initialization of the learners to test and their related environment:
    # the list is composed of tuples (Learner, Environment)
    print(f'\nrunning experiment {e + 1}/{n_experiments}...\n')
    test_instances = []
    
    for learner in learners_to_test:
        context_learner = ContextualLearner(features, learner, **bandit_args)
        test_instances.append(
            (context_learner,
             CompleteEnvironment(src=src),
             ContextGenerator(features=features,
                              contextual_learner=context_learner,
                              update_frequency=cg_frequency,
                              start_from=cg_start_from,
                              confidence=cg_confidence,
                              verbose=1))
        )
    for t in range(T):
        for context_learner, env, context_generator in test_instances:
            #print(f'##### DAY {t} ######')
            context_learner.next_day()
            past_arms = env.get_selected_arms_at_day(t - 30, keep=False, filter_purchases=True)
            past_features = env.get_collected_user_features_at_day(t - 30, keep=False, filter_purchases=True)
            month_purchases = env.get_next_purchases_at_day(t, keep=False, filter_purchases=True)
            if month_purchases is not None:
                context_learner.update_next_purchases(past_arms, month_purchases, past_features)

            pulled_arms = context_learner.pull_arm()
            daily_rewards, _, _ = env.day_round(pulled_arms, selected_bid=selected_bid, fixed_adv=True)
            daily_users_features = env.get_collected_user_features_at_day(t)
            daily_pulled_arms = env.get_selected_arms_at_day(t)
            
            context_learner.update(daily_rewards, daily_pulled_arms, daily_users_features)
            context_generator.collect_daily_data(daily_pulled_arms, 
                                                 daily_rewards, 
                                                 daily_users_features,
                                                 next_purchases=month_purchases, 
                                                 past_pulled_arms=past_arms,
                                                 past_features=past_features)
    for learner, _, _ in test_instances:
        learner.next_day()
        rewards_per_experiment[learner.base_learner_class.LEARNER_NAME].append(learner.get_daily_rewards())
        context_split_per_experiment[learner.base_learner_class.LEARNER_NAME].append(learner.get_splits_count())
        days_of_split[learner.base_learner_class.LEARNER_NAME].append(context_generator.metadata['SPLIT_DAYS'])
    
    # end -> save rhe results.
# Out:
# running experiment 1/8...
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.3935260263090377, 2.4807962391633724]
# 	Value before the split: 2.348657716178249
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': False} and {'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.5382199962069687, 2.4291144547334858]
# 	Value before the split: 2.3068213647213307
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.050343532449257]
# 	Value before the split: 1.107869448013413
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.005375379714012]
# 	Value before the split: 3.8910234503424697
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': True, 'feature-1': False} and {'feature-2': True, 'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [UCB]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.8998486657982514]
# 	Value before the split: 1.177568079942368
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [3.844755096916599]
# 	Value before the split: 3.77567293117109
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': True, 'feature-2': False} and {'feature-1': True, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0462491920930126]
# 	Value before the split: 1.0926341223275176
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.5379391565157124]
# 	Value before the split: 1.0922649895195928
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.026651092471101]
# 	Value before the split: 1.0705459697492106
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7097436513035866]
# 	Value before the split: 1.1181496376993183
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=100 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0299787393105917]
# 	Value before the split: 1.0683975554453815
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=100 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.6450494633361119]
# 	Value before the split: 1.109891061023646
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=110 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0154830951817375]
# 	Value before the split: 1.0519978686289453
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=110 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7518225252589015]
# 	Value before the split: 0.9689763809125418
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0054375870956025]
# 	Value before the split: 1.0388667622783054
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.6419425861569807]
# 	Value before the split: 0.9637851695389341
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=130 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0239077651691846]
# 	Value before the split: 1.035352330323878
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=130 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.739556915961401]
# 	Value before the split: 1.066136556182229
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=140 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0374520525652526]
# 	Value before the split: 1.0553631120536031
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=140 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7298455220259046]
# 	Value before the split: 0.9650093084345578
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0417934793812025]
# 	Value before the split: 1.0644286214369891
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7230822902051812]
# 	Value before the split: 0.9576972355354179
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=160 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0343654301226817]
# 	Value before the split: 1.0637775405207957
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=160 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7240525691355244]
# 	Value before the split: 0.5916106238889717
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False, 'feature-2': False} and {'feature-1': False, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=170 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0341252163664503]
# 	Value before the split: 1.0621449261594276
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0351304292153034]
# 	Value before the split: 1.0625863413106744
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=190 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0313255543009388]
# 	Value before the split: 1.058094773079032
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=200 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.027136500241623]
# 	Value before the split: 1.0533855137654027
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0273390987346422]
# 	Value before the split: 1.0534407736985245
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=220 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.028113881374768]
# 	Value before the split: 1.0532778721965947
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=230 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.026064216474956]
# 	Value before the split: 1.0511193874952376
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.027011000836854]
# 	Value before the split: 1.047397617765395
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=250 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0298973881059312]
# 	Value before the split: 1.0447435874843933
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=260 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0298888913802426]
# 	Value before the split: 1.0478703374083647
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0314640849973227]
# 	Value before the split: 1.0481233829147278
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=280 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0423701817639672]
# 	Value before the split: 1.0491977002616537
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=290 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0408193357967777]
# 	Value before the split: 1.049382028917137
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=300 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0444119997129038]
# 	Value before the split: 1.049082012278768
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=310 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0449486749664527]
# 	Value before the split: 1.0456684433455912
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=320 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0393163224719841]
# 	Value before the split: 1.0485694442148865
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=330 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0407910472287087]
# 	Value before the split: 1.0487384593165048
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=340 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0391594033572529]
# 	Value before the split: 1.0477776587461156
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=350 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.035407301676476]
# 	Value before the split: 1.0497874510707488
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=360 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0316704366454166]
# 	Value before the split: 1.051470664394446
#
#
# running experiment 2/8...
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.5082774070139493, 2.464880585365338]
# 	Value before the split: 2.370175499642487
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.4769213241456534, 2.3783419915822916]
# 	Value before the split: 2.381065243232652
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0594143709580457]
# 	Value before the split: 1.0814887651644807
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.1144625035094045]
# 	Value before the split: 4.056667086196798
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': True, 'feature-2': False} and {'feature-1': True, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [UCB]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.6020886744761265]
# 	Value before the split: 0.7099571214231158
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [3.5043705883465077]
# 	Value before the split: 2.567674942184032
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': True, 'feature-2': False} and {'feature-1': True, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.049496432893652]
# 	Value before the split: 1.0820991845645354
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7366505338160462]
# 	Value before the split: 1.090385149715
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.060028075647969]
# 	Value before the split: 1.088543084199132
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7948429825858301]
# 	Value before the split: 1.055608613304023
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=100 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0417961914815792]
# 	Value before the split: 1.0743311901597876
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=100 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7779610184713017]
# 	Value before the split: 1.0583665261848183
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=110 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0582047876709582]
# 	Value before the split: 1.0830197382640943
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=110 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.6865912186031446]
# 	Value before the split: 0.5591910810830837
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False, 'feature-2': False} and {'feature-1': False, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0171698976118433]
# 	Value before the split: 1.0475145508769053
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=130 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0175962049168605]
# 	Value before the split: 1.0513855395073808
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=140 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0309304213381079]
# 	Value before the split: 1.0640611015040944
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0265684629692036]
# 	Value before the split: 1.0561932442552384
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=160 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0148062529621407]
# 	Value before the split: 1.0454872706075642
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=170 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0139589388937382]
# 	Value before the split: 1.043485623176712
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.018888423814245]
# 	Value before the split: 1.0487735066564705
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=190 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0318206933014693]
# 	Value before the split: 1.0607267568873093
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=200 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0292138022173427]
# 	Value before the split: 1.0560621940881627
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.023044105548697]
# 	Value before the split: 1.0491431646276619
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=220 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0201977578443353]
# 	Value before the split: 1.0454588003395486
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=230 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0197255633887372]
# 	Value before the split: 1.044764180138531
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0152955121121132]
# 	Value before the split: 1.03938050038836
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=250 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0170072857958128]
# 	Value before the split: 1.0403822127919513
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=260 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0198951225826434]
# 	Value before the split: 1.0438249197877851
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0216313390292204]
# 	Value before the split: 1.0456613100892231
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=280 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0183025533712247]
# 	Value before the split: 1.0423084762698869
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=290 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.018023728703557]
# 	Value before the split: 1.0414250860049932
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=300 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0159431583287704]
# 	Value before the split: 1.037634516019179
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=310 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0175351266652177]
# 	Value before the split: 1.0363572489828847
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=320 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0225490581480532]
# 	Value before the split: 1.0403794041991392
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=330 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0247062103155749]
# 	Value before the split: 1.0404143351688668
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=340 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0274795225693996]
# 	Value before the split: 1.042913709422794
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=350 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0279675294606676]
# 	Value before the split: 1.0454859045528708
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=360 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0297186836517414]
# 	Value before the split: 1.0482740284199317
#
#
# running experiment 3/8...
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.9763534551279385, 2.78251703745119]
# 	Value before the split: 2.8605854471644268
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.438428771558721, 2.4757400750495875]
# 	Value before the split: 2.464742960123493
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': False} and {'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0380258437140233]
# 	Value before the split: 1.0707424815388973
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.169083252200732]
# 	Value before the split: 4.1869216193209455
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [UCB]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.9256986422046201]
# 	Value before the split: 0.7395622772862441
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': False, 'feature-1': False} and {'feature-2': False, 'feature-1': True}
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [3.403838219236101]
# 	Value before the split: 4.182018748906724
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0613701368037807]
# 	Value before the split: 1.0887152359115948
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.1961647028584546]
# 	Value before the split: 4.265827733138366
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.083982502389701]
# 	Value before the split: 4.064587752295853
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': True, 'feature-1': False} and {'feature-2': True, 'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0397887343358685]
# 	Value before the split: 1.0702159549278665
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.197140735943071]
# 	Value before the split: 4.253106625757761
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=100 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0227586698269697]
# 	Value before the split: 1.0407613498556125
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.21199681019517]
# 	Value before the split: 4.2600456859623925
# -------------------- RUNNING CONTEXT GENERATOR@t=110 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0057839068079213]
# 	Value before the split: 1.0280996984925073
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.24883829653805]
# 	Value before the split: 4.305521838333206
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.997316495983601]
# 	Value before the split: 1.026291432915239
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.257898755023298]
# 	Value before the split: 4.298438430377645
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=130 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0044066159572753]
# 	Value before the split: 1.032311066746999
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.240507763406017]
# 	Value before the split: 4.275291918444396
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=140 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.9908077887334408]
# 	Value before the split: 1.018895616340331
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.226183140918024]
# 	Value before the split: 4.264017903027966
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.9991799669444994]
# 	Value before the split: 1.0277307386181829
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.201448077368587]
# 	Value before the split: 4.227379099507416
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=160 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.9983987851745663]
# 	Value before the split: 1.0272495812651432
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.182492108241603]
# 	Value before the split: 4.2095830445290225
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=170 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.997632704813716]
# 	Value before the split: 1.0256050591461088
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.183089179087248]
# 	Value before the split: 4.207852802759118
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.9981690585190075]
# 	Value before the split: 1.0255902550639913
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.183114693215001]
# 	Value before the split: 4.209875955573171
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=190 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0027999710387394]
# 	Value before the split: 1.0293551150423657
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.190882599443711]
# 	Value before the split: 4.210379806851467
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=200 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.995665706938359]
# 	Value before the split: 1.0214925874040799
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.198598853223963]
# 	Value before the split: 4.213043988181238
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.9964823865120143]
# 	Value before the split: 1.0210856550724645
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.192523492498277]
# 	Value before the split: 4.209669876083894
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=220 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.9992935450108535]
# 	Value before the split: 1.0233300196227304
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.194592941747988]
# 	Value before the split: 4.208025442301502
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=230 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0169117896951967]
# 	Value before the split: 1.023054344733175
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.201277490348234]
# 	Value before the split: 4.209363604786597
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [1.0759102316049596]
# 	Value before the split: 1.0722994688118868
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False, 'feature-2': False} and {'feature-1': False, 'feature-2': True}
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.196445270780139]
# 	Value before the split: 4.203886361638519
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=250 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.191682695774681]
# 	Value before the split: 4.191676517139385
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': True, 'feature-2': False} and {'feature-1': True, 'feature-2': True}
#
# running experiment 4/8...
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.419512285282569, 2.4955802312500133]
# 	Value before the split: 2.475006032742812
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': False} and {'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.504248332057619, 2.505428346256455]
# 	Value before the split: 2.399724143807432
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': False} and {'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0027480011722225]
# 	Value before the split: 1.0803916774678186
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.317964226821924]
# 	Value before the split: 4.071171393849162
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': True, 'feature-1': False} and {'feature-2': True, 'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [UCB]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.9014157421696581]
# 	Value before the split: 1.056804022830292
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [3.237787183895976]
# 	Value before the split: 4.136135801721224
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.9976466564813649]
# 	Value before the split: 1.0710249297467394
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [UCB]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.49724483211624326]
# 	Value before the split: 0.5172893441468788
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [3.355488740844393]
# 	Value before the split: 4.122183208902216
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.9634784647168372]
# 	Value before the split: 1.0327504225602278
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 [UCB]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.6704259912338895]
# 	Value before the split: 0.5311680880798564
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': False, 'feature-1': False} and {'feature-2': False, 'feature-1': True}
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [3.375716340462892]
# 	Value before the split: 4.142381789656929
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=100 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.9624118259989796]
# 	Value before the split: 1.0011233224992815
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=100 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [3.3439379252003]
# 	Value before the split: 3.113638132419721
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': True, 'feature-1': False} and {'feature-2': True, 'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=110 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.9650534173969021]
# 	Value before the split: 0.9857159403344713
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.9803710386081317]
# 	Value before the split: 0.9779740462138641
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': False, 'feature-1': False} and {'feature-2': False, 'feature-1': True}
#
# running experiment 5/8...
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# ...
#  splitting into -> {'feature-2': False, 'feature-1': False} and {'feature-2': False, 'feature-1': True}
#
# running experiment 8/8...
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.578358193793422, 2.776147099552842]
# 	Value before the split: 2.6447435431728734
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': False} and {'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-1', 'feature-2']
#
# Analysis of the feature `feature-1`...
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [2.4514069215063206, 2.408402620723892]
# 	Value before the split: 2.345637108705555
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0051943901109577]
# 	Value before the split: 1.0963275226935782
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.284920377960097]
# 	Value before the split: 4.4195162409737545
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=70 [UCB]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7394773279010418]
# 	Value before the split: 1.098114446915342
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.03495308820118]
# 	Value before the split: 3.921504980373243
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': True, 'feature-2': False} and {'feature-1': True, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0057532568063512]
# 	Value before the split: 1.0973333378972239
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.249624306169072]
# 	Value before the split: 4.361410907377471
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=80 [UCB]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
#
# Analysis of the feature `feature-2`...
# 	Values after the split: [0.7540903364261986]
# 	Value before the split: 0.6447307620740386
#
# 	"Best feature: "feature-2
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False, 'feature-2': False} and {'feature-1': False, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.9978432442472635]
# 	Value before the split: 1.089148745262484
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.1759711673286795]
# 	Value before the split: 4.263928740504817
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=100 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [0.961279853614746]
# 	Value before the split: 1.0015458086877642
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.15921511934947]
# 	Value before the split: 4.236163706406754
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=110 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0006530912782265]
# 	Value before the split: 1.0411255452797878
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.148277065915859]
# 	Value before the split: 4.188575758425681
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0377633504725834]
# 	Value before the split: 1.0736742806408826
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.1445857451830435]
# 	Value before the split: 4.164625824835539
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=130 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.021258751883652]
# 	Value before the split: 1.0467708466409462
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.108384500931639]
# 	Value before the split: 4.126145498702335
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=140 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0538129162065801]
# 	Value before the split: 1.0829865589911447
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.135566001709517]
# 	Value before the split: 4.166200839544792
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0451796210412971]
# 	Value before the split: 1.07534681400851
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.152707015136799]
# 	Value before the split: 4.18797870672578
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=160 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0343019271532847]
# 	Value before the split: 1.0636757863290003
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.190661599046954]
# 	Value before the split: 4.209325454999668
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=170 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0363936079211578]
# 	Value before the split: 1.064163755067246
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.160131539815386]
# 	Value before the split: 4.20106901803699
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0308614169171288]
# 	Value before the split: 1.0570790170728896
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.160780588759684]
# 	Value before the split: 4.1840967763033285
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=190 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0275390133134432]
# 	Value before the split: 1.0528269318330181
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.169075006502386]
# 	Value before the split: 4.171190407250504
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=200 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0284743043425602]
# 	Value before the split: 1.056017295539645
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.176389483922936]
# 	Value before the split: 4.191031077033835
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 [TS]--------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0216979370299926]
# 	Value before the split: 1.0484257437045026
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.222371311385117]
# 	Value before the split: 4.198598606236691
#
# 	"Best feature: "feature-1
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': True, 'feature-1': False} and {'feature-2': True, 'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=220 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0189990014378638]
# 	Value before the split: 1.0438771407704575
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=230 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.019800642333892]
# 	Value before the split: 1.043549293298738
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0206861677068597]
# 	Value before the split: 1.0437523338461079
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=250 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.023385833569745]
# 	Value before the split: 1.046388090777128
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=260 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0236732998210498]
# 	Value before the split: 1.0467567981729489
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.026579280896498]
# 	Value before the split: 1.049127134153344
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=280 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.024078497340029]
# 	Value before the split: 1.046069525691179
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=290 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0292909335017084]
# 	Value before the split: 1.0510242753677117
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=300 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0290005622289398]
# 	Value before the split: 1.0500110776967009
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=310 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.023106132459811]
# 	Value before the split: 1.0432322577165494
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=320 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0280064068988022]
# 	Value before the split: 1.0473447589275733
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=330 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0301411471298412]
# 	Value before the split: 1.049827435899266
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=340 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0297718326107024]
# 	Value before the split: 1.0492264356548968
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=350 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0279824678247147]
# 	Value before the split: 1.0476802002694863
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=360 [TS]--------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
#
# Analysis of the feature `feature-1`...
# 	Values after the split: [1.0299849264359808]
# 	Value before the split: 1.0496244646084847

# %%
plt.figure()
plt.ylabel("num_splits")
plt.xlabel("experiment")
for val in context_split_per_experiment.values():
    plt.plot(val, '--o')
plt.legend(context_split_per_experiment.keys())
plt.show()

# %%
# Plotting the results
plt.figure(figsize=(10,8))
plt.ylabel("Regret")
plt.xlabel("day")
plt.plot(4000*np.sqrt(np.linspace(0,364,365)), '--')
for val in rewards_per_experiment.values():
    plt.plot(np.cumsum(np.mean(disaggr_opt - val, axis=0)))

plt.legend(['O(sqrt-T)']+list(rewards_per_experiment.keys()))
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.xlabel("day")
plt.ylabel("daily reward")
plt.plot([disaggr_opt]*T, '--g', label='clairwoyant')
plt.plot([aggr_opt]*T, '--c', label='aggr_clairwoyant')
for key in rewards_per_experiment:
    plt.plot(np.mean(rewards_per_experiment[key], axis=0), label=key)

plt.legend(loc='best')
plt.show()
