# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
os.chdir('/content/drive/MyDrive/DataIntelligenceApplications/')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
# Step 5 with the complete environment

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

from data_generators.standard_generator import StandardDataGenerator
from environments.complete_environment import CompleteEnvironment
from learners.GTS_Learner import GTS_Learner
from learners.GPTS_Learner_v3 import GPTS_Learner

# %%
src = 'src/basic005.json'
dg = StandardDataGenerator(src)

# %%
sel_price = 4
print('\n', 15 * '-', 'SIMULATION PARAMS', '-' * 15)
T = 365
n_experiments = 5
print(f'Time horizon: {T} days')
print(f'Num. experiments: {n_experiments}')
# Out:
#  --------------- SIMULATION PARAMS ---------------
# Time horizon: 365 days
# Num. experiments: 5

# %%
dg = StandardDataGenerator(src)
for bid in range(0, len(dg.get_bids())):
  conv_rate = dg.get_conversion_rates(mode='aggregate', bid=bid)[sel_price]
  tau = dg.get_future_purchases(mode='aggregate', bid=bid)[sel_price]
  cpc = dg.get_costs_per_click(mode='aggregate', bid=bid)[bid]
  exp = dg.get_daily_clicks(mode='aggregate')[bid] * (conv_rate * dg.get_margins()[sel_price] * (1 + tau) - cpc)
  print(f'BID: {bid}')
  print(f'\t- conv_rate={conv_rate},')
  print(f'\t- tau={tau},')
  print(f'\t- cpc={cpc},')
# Out:
# BID: 0
# 	- conv_rate=0.178,
# 	- tau=0.868,
# 	- cpc=0.295,
# BID: 1
# 	- conv_rate=0.176,
# 	- tau=0.839,
# 	- cpc=0.343,
# BID: 2
# 	- conv_rate=0.173,
# 	- tau=0.814,
# 	- cpc=0.391,
# BID: 3
# 	- conv_rate=0.17,
# 	- tau=0.772,
# 	- cpc=0.486,
# BID: 4
# 	- conv_rate=0.167,
# 	- tau=0.739,
# 	- cpc=0.58,
# BID: 5
# 	- conv_rate=0.163,
# 	- tau=0.703,
# 	- cpc=0.719,
# BID: 6
# 	- conv_rate=0.16,
# 	- tau=0.678,
# 	- cpc=0.856,
# BID: 7
# 	- conv_rate=0.159,
# 	- tau=0.665,
# 	- cpc=0.946,
# BID: 8
# 	- conv_rate=0.157,
# 	- tau=0.642,
# 	- cpc=1.168,
# BID: 9
# 	- conv_rate=0.155,
# 	- tau=0.628,
# 	- cpc=1.383,

# %%
#learners_to_test = [GTS_Learner, GPTS_Learner]
learners_to_test = [GTS_Learner]
rewards_per_experiment = {}
for learner in learners_to_test:
    rewards_per_experiment[learner.LEARNER_NAME] = []

# %%
for e in range(n_experiments):
    print(f'running experiment {e + 1}/{n_experiments}...\n')
    test_instances = []
    for learner in learners_to_test:
        test_instances.append((learner(dg.get_bids()),
                               CompleteEnvironment(src=src)))
    for t in range(T):
        for learner, env in test_instances:
            sel_bid = learner.pull_arm()
            out = env.day_round(sel_price, sel_bid, fixed_price=True)
            print(f'DAY {t}:\n\t sel_bid={sel_bid},\n\t out={out}')
            learner.update(sel_bid, out)
    for learner, _ in test_instances:
        rewards_per_experiment[learner.LEARNER_NAME].append(learner.daily_collected_rewards)
# Out:
# Streaming output truncated to the last 5000 lines.
# DAY 161:
# 	 sel_bid=1,
# 	 out={'n_clicks': 408.0, 'cpc': 0.3443161764705882, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY
 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 361:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.34447014925373126, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 362:
# 	 sel_bid=1,
# 	 out={'n_clicks': 404.0, 'cpc': 0.3444282178217822, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 363:
# 	 sel_bid=1,
# 	 out={'n_clicks': 401.0, 'cpc': 0.3423690773067332, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 364:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.3460597014925373, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# running experiment 2/5...
#
# DAY 0:
# 	 sel_bid=8,
# 	 out={'n_clicks': 560.0, 'cpc': 1.1706875, 'margin': 7, 'tau': 0.642, 'conv_rates': 0.157}
# DAY 1:
# 	 sel_bid=1,
# 	 out={'n_clicks': 405.0, 'cpc': 0.3416938271604938, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 2:
# 	 sel_bid=7,
# 	 out={'n_clicks': 534.0, 'cpc': 0.9539494382022472, 'margin': 7, 'tau': 0.665, 'conv_rates': 0.159}
# DAY 3:
# 	 sel_bid=3,
# 	 out={'n_clicks': 460.0, 'cpc': 0.4877217391304347, 'margin': 7, 'tau': 0.772, 'conv_rates': 0.17}
# DAY 4:
# 	 sel_bid=0,
# 	 out={'n_clicks': 372.0, 'cpc': 0.29476344086021505, 'margin': 7, 'tau': 0.868, 'conv_rates': 0.178}
# DAY 5:
# 	 sel_bid=7,
# 	 out={'n_clicks': 543.0, 'cpc': 0.9391970534069982, 'margin': 7, 'tau': 0.665, 'conv_rates': 0.159}
# DAY 6:
# 	 sel_bid=2,
# 	 out={'n_clicks': 424.0, 'cpc': 0.39037264150943396, 'margin': 7, 'tau': 0.814, 'conv_rates': 0.173}
# DAY 7:
# 	 sel_bid=8,
# 	 out={'n_clicks': 557.0, 'cpc': 1.1573716337522444, 'margin': 7, 'tau': 0.642, 'conv_rates': 0.157}
# DAY 8:
# 	 sel_bid=3,
# 	 out={'n_clicks': 456.0, 'cpc': 0.48657894736842106, 'margin': 7, 'tau': 0.772, 'conv_rates': 0.17}
# DAY 9:
# 	 sel_bid=8,
# 	 out={'n_clicks': 559.0, 'cpc': 1.1659033989266547, 'margin': 7, 'tau': 0.642, 'conv_rates': 0.157}
# DAY 10:
# 	 sel_bid=2,
# 	 out={'n_clicks': 425.0, 'cpc': 0.3917788235294118, 'margin': 7, 'tau': 0.814, 'conv_rates': 0.173}
# DAY 11:
# 	 sel_bid=9,
# 	 out={'n_clicks': 576.0, 'cpc': 1.3754704861111111, 'margin': 7, 'tau': 0.628, 'conv_rates': 0.155}
# DAY 12:
# 	 sel_bid=5,
# 	 out={'n_clicks': 512.0, 'cpc': 0.7194453125, 'margin': 7, 'tau': 0.703, 'conv_rates': 0.163}
# DAY 13:
# 	 sel_bid=5,
# 	 out={'n_clicks': 514.0, 'cpc': 0.7175817120622567, 'margin': 7, 'tau': 0.703, 'conv_rates': 0.163}
# DAY 14:
# 	 sel_bid=1,
# 	 out={'n_clicks': 405.0, 'cpc': 0.34216049382716046, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 15:
# 	 sel_bid=6,
# 	 out={'n_clicks': 535.0, 'cpc': 0.8602728971962617, 'margin': 7, 'tau': 0.678, 'conv_rates': 0.16}
# DAY 16:
# 	 sel_bid=9,
# 	 out={'n_clicks': 569.0, 'cpc': 1.3738084358523726, 'margin': 7, 'tau': 0.628, 'conv_rates': 0.155}
# DAY 17:
# 	 sel_bid=6,
# 	 out={'n_clicks': 534.0, 'cpc': 0.8521516853932584, 'margin': 7, 'tau': 0.678, 'conv_rates': 0.16}
# DAY 18:
# 	 sel_bid=4,
# 	 out={'n_clicks': 486.0, 'cpc': 0.5797613168724279, 'margin': 7, 'tau': 0.739, 'conv_rates': 0.167}
# DAY 19:
# 	 sel_bid=0,
# 	 out={'n_clicks': 380.0, 'cpc': 0.29686315789473683, 'margin': 7, 'tau': 0.868, 'conv_rates': 0.178}
# DAY

# 	 sel_bid=1,
# 	 out={'n_clicks': 403.0, 'cpc': 0.3423846153846154, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 326:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.3436094527363185, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 327:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.3436666666666667, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 328:
# 	 sel_bid=1,
# 	 out={'n_clicks': 403.0, 'cpc': 0.3443076923076923, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 329:
# 	 sel_bid=1,
# 	 out={'n_clicks': 404.0, 'cpc': 0.34927227722772275, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 330:
# 	 sel_bid=1,
# 	 out={'n_clicks': 405.0, 'cpc': 0.34348395061728393, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 331:
# 	 sel_bid=1,
# 	 out={'n_clicks': 401.0, 'cpc': 0.3407381546134664, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 332:
# 	 sel_bid=1,
# 	 out={'n_clicks': 400.0, 'cpc': 0.341205, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 333:
# 	 sel_bid=1,
# 	 out={'n_clicks': 403.0, 'cpc': 0.3450719602977667, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 334:
# 	 sel_bid=1,
# 	 out={'n_clicks': 403.0, 'cpc': 0.34279652605459054, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 335:
# 	 sel_bid=1,
# 	 out={'n_clicks': 403.0, 'cpc': 0.3414317617866005, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 336:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.3430000000000001, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 337:
# 	 sel_bid=1,
# 	 out={'n_clicks': 403.0, 'cpc': 0.34459801488833747, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 338:
# 	 sel_bid=1,
# 	 out={'n_clicks': 404.0, 'cpc': 0.343990099009901, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 339:
# 	 sel_bid=1,
# 	 out={'n_clicks': 404.0, 'cpc': 0.3457153465346534, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 340:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.3475646766169154, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 341:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.34294029850746266, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 342:
# 	 sel_bid=1,
# 	 out={'n_clicks': 403.0, 'cpc': 0.3440769230769231, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 343:
# 	 sel_bid=1,
# 	 out={'n_clicks': 403.0, 'cpc': 0.34194044665012413, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 344:
# 	 sel_bid=1,
# 	 out={'n_clicks': 407.0, 'cpc': 0.34845454545454546, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 345:
# 	 sel_bid=1,
# 	 out={'n_clicks': 408.0, 'cpc': 0.343578431372549, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 346:
# 	 sel_bid=1,
# 	 out={'n_clicks': 401.0, 'cpc': 0.34060099750623446, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 347:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.34068656716417917, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 348:
# 	 sel_bid=1,
# 	 out={'n_clicks': 399.0, 'cpc': 0.34308270676691727, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 349:
# 	 sel_bid=1,
# 	 out={'n_clicks': 406.0, 'cpc': 0.3447192118226601, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 350:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.3474776119402985, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 351:
# 	 sel_bid=1,
# 	 out={'n_clicks': 402.0, 'cpc': 0.343776119402985, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 352:
# 	 sel_bid=1,
# 	 out={'n_clicks': 399.0, 'cpc': 0.34095989974937346, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 353:
# 	 sel_bid=1,
# 	 out={'n_clicks': 400.0, 'cpc': 0.343605, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 354:
# 	 sel_bid=1,
# 	 out={'n_clicks': 405.0, 'cpc': 0.3453851851851852, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 355:
# 	 sel_bid=1,
# 	 out={'n_clicks': 404.0, 'cpc': 0.342, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 356:
# 	 sel_bid=1,
# 	 out={'n_clicks': 400.0, 'cpc': 0.34448999999999996, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 357:
# 	 sel_bid=1,
# 	 out={'n_clicks': 406.0, 'cpc': 0.34179556650246307, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 358:
# 	 sel_bid=1,
# 	 out={'n_clicks': 401.0, 'cpc': 0.33868578553615963, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 359:
# 	 sel_bid=1,
# 	 out={'n_clicks': 404.0, 'cpc': 0.3459232673267326, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 360:
# 	 sel_bid=1,
# 	 out={'n_clicks': 404.0, 'cpc': 0.34374257425742577, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 361:
# 	 sel_bid=1,
# 	 out={'n_clicks': 404.0, 'cpc': 0.34204702970297035, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 362:
# 	 sel_bid=1,
# 	 out={'n_clicks': 400.0, 'cpc': 0.3428675, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 363:
# 	 sel_bid=1,
# 	 out={'n_clicks': 401.0, 'cpc': 0.3447306733167082, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}
# DAY 364:
# 	 sel_bid=1,
# 	 out={'n_clicks': 396.0, 'cpc': 0.34333838383838383, 'margin': 7, 'tau': 0.839, 'conv_rates': 0.176}

# %%
#opt
def get_opt(src, sel_price):
    dg = StandardDataGenerator(src)
    print('src:\t',dg.get_source())
    expected_rewards = np.array([])
    for bid in range(0, len(dg.get_bids())):
        conv_rate = dg.get_conversion_rates(mode='aggregate', bid=bid)[sel_price]
        tau = dg.get_future_purchases(mode='aggregate', bid=bid)[sel_price]
        cpc = dg.get_costs_per_click(mode='aggregate', bid=bid)[bid]
        exp = dg.get_daily_clicks(mode='aggregate')[bid] * (conv_rate * dg.get_margins()[sel_price] * (1 + tau) - cpc)
        expected_rewards = np.append(expected_rewards, exp)
    
    print(expected_rewards)
    return np.max(expected_rewards)

# %%
opt_value = get_opt(src, sel_price)
# Out:
# src:	 src/basic005.json
# [766.81183856 774.75023808 766.28976744 743.0981926  701.89745366
#  625.37138938 543.34480512 491.13102444 356.88051368 219.78293626]

# %%
plt.figure(figsize=(10,8))
plt.ylabel("Regret")
plt.xlabel("day")
plt.plot(1000*np.sqrt(np.linspace(0,364,365)), '--')
for val in rewards_per_experiment.values():
    plt.plot(np.cumsum(np.mean(opt_value - val, axis=0)))

plt.legend(['O(sqrt-T)']+list(rewards_per_experiment.keys()))
plt.show()
