# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

from data_generators.basic_generator import BasicDataGenerator
from environments.pricing_environment import PricingEnvironment
from learners.pricing.thompson_sampling import ThompsonSampling
from learners.pricing.ucb import UCB
from learners.pricing.contextual_learner import ContextualLearner
from environments.contextual_environment import ContextualEnvironment
from utils.context_generator import ContextGenerator

# %%
dg = BasicDataGenerator(filename='src/basic001.json')
sel_bid = 3
fixed_clicks = np.rint(dg.get_daily_clicks(mode='aggregate')[sel_bid]).astype(int)
fixed_cost = dg.get_costs_per_click(mode='aggregate')[sel_bid]
env_params = {
    'features': dg.get_features(),
    'customer_classes': dg.get_classes(),
    'conversion_rates': dg.get_conversion_rates(mode='all'),
    'future_purchases': dg.get_future_purchases(mode='all'),
    'daily_clicks': fixed_clicks,
    'cost_per_click': fixed_cost
}
margins = dg.get_margins()
fractions = []
for cl in dg.get_classes().values():
    fractions.append(cl['fraction'])

args = {
    'arm_values': dg.get_margins()
}

# %%
print('\n', 15 * '-', 'SIMULATION PARAMS', '-' * 15)
T = 365
n_experiments = 10
print(f'Time horizon: {T} days')
print(f'Num. experiments: {n_experiments}')
# Out:
#  --------------- SIMULATION PARAMS ---------------
# Time horizon: 365 days
# Num. experiments: 10

# %%
opt_arms = []
global_opt = 0

for i, conv_rate in enumerate(dg.get_conversion_rates(mode='all')):
    opt_arm = np.argmax(margins[i] * conv_rate * (1 + dg.get_future_purchases()[i]) - fixed_cost)
    opt_value = np.max(margins[i] * conv_rate * (1 + dg.get_future_purchases()[i]) - fixed_cost)
    opt_arms.append((opt_arm, opt_value))
    global_opt += fractions[i]*opt_value

print(f'N_ARMS: {len(margins)}')
print(f'Optimal arm: {str(opt_arms)}')
print(f'Fractions: {fractions}')
print(f'Global opt: {global_opt}')
# Out:
# N_ARMS: 10
# Optimal arm: [(1, 19.912999999999997), (0, 8.063), (0, 15.543000000000001)]
# Fractions: [0.2, 0.35, 0.45]
# Global opt: 13.799

# %%
learners_to_test = [ThompsonSampling, UCB]
rewards_per_experiment = {}
context_split_experiment = {}
for learner in learners_to_test:
    rewards_per_experiment[learner.LEARNER_NAME] = []
    context_split_experiment[learner.LEARNER_NAME] = []

print(f'N_ROUNDS: {T}')
print(f'N_EXPERIMENTS: {n_experiments}')
print(f'ALGORITHMS: {list(rewards_per_experiment.keys())}')
start_from = 60
frequency = 15
confidence = 0.001
# Out:
# N_ROUNDS: 365
# N_EXPERIMENTS: 10
# ALGORITHMS: ['TS-Pricing', 'UCB-Pricing']

# %%
for e in range(n_experiments):
    # Initialization of the learners to test and their related environment:
    # the list is composed of tuples (Learner, Environment)
    print(f'{"//"*12} exp#{e} {"//"*12}')
    test_instances = []
    for learner in learners_to_test:
        context_learner = ContextualLearner(dg.get_features(), learner, **args)
        test_instances.append(
            (context_learner,
            ContextualEnvironment(**env_params),
            ContextGenerator(dg.get_features(), context_learner, update_frequency=frequency, start_from=start_from, confidence=confidence))
        )
        
    for t in range(T):
        for context_learner, env, context_generator  in test_instances:
            context_learner.next_day()
            past_arms = None
            past_features = None
            month_purchases = env.get_next_purchases_at_day(t, keep=False)
            if month_purchases is not None:
                past_arms = env.get_selected_arms_at_day(t - 30, keep=False)
                past_features= env.get_collected_user_features_at_day(t - 30, keep=False)
                context_learner.update_next_purchases(past_arms,
                                                      month_purchases, 
                                                      past_features)

            pulled_arms = context_learner.pull_arms()
            daily_rewards = env.day_round(pulled_arms)
            daily_users_features = env.get_collected_user_features_at_day(t)
            daily_pulled_arms = env.get_selected_arms_at_day(t)

            context_learner.update(daily_rewards, daily_pulled_arms, daily_users_features)
            context_generator.collect_daily_data(daily_pulled_arms, daily_rewards, daily_users_features, 
                                                 next_purchases=month_purchases)
        
    for learner, _, _ in test_instances:
        learner.next_day()
        rewards_per_experiment[learner.base_learner_class.LEARNER_NAME].append(learner.get_daily_rewards())
        context_split_experiment[learner.base_learner_class.LEARNER_NAME].append(learner.get_splits_count())
# Out:
# //////////////////////// exp#0 ////////////////////////
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [13.12009398390663, 13.256182021455292]
# 	Value before the split: 13.709671413594913
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.40499061961047, 8.208511136964537]
# 	Value before the split: 12.175996736092149
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=75 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.440828026191141, 12.818026308772788]
# 	Value before the split: 12.759190484740595
#
# 	best_feature='feature-1'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=75 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [7.9045709946020555, 7.92172861346534]
# 	Value before the split: 12.017129520044074
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.484686141368407]
# 	Value before the split: 12.059557798143354
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.913766604167662]
# 	Value before the split: 14.578276699590742
#
# 	best_feature='feature-2'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': True, 'feature-2': False} and {'feature-1': True, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.768766023700417, 10.196511392006059]
# 	Value before the split: 12.035139539659973
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=105 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.48966760540662]
# 	Value before the split: 12.021365163359016
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=105 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.758059741627841, 10.444946393800915]
# 	Value before the split: 12.406350274168835
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.249606263096858]
# 	Value before the split: 11.734014911835038
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [7.8382435786793465, 10.473532673079138]
# 	Value before the split: 12.454632676410455
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=135 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.085731883625554]
# 	Value before the split: 11.535579553146242
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=135 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.114071188309842, 10.744814380840406]
# 	Value before the split: 9.761281089059375
#
# 	best_feature='feature-1'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.889998123656397]
# 	Value before the split: 11.309731167491531
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [7.084587165712232]
# 	Value before the split: 8.40486612373945
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.614260358277885]
# 	Value before the split: 14.724065613875021
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=165 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.97663498877617]
# 	Value before the split: 11.380371330127973
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=165 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.816114020075737]
# 	Value before the split: 11.653408714142124
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.614294754083366]
# 	Value before the split: 15.004933671501053
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.020040157315382]
# 	Value before the split: 11.407782233427614
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [7.348846566512124]
# 	Value before the split: 11.655022904519447
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [7.976289913865362]
# 	Value before the split: 15.138974640188824
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=195 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.990949745318384]
# 	Value before the split: 11.361196135361542
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=195 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.832541323058931]
# 	Value before the split: 11.558559554157291
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [7.989416059160057]
# 	Value before the split: 15.16043775174191
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.01283849110215]
# 	Value before the split: 11.369842302539212
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.902194617579966]
# 	Value before the split: 11.522082318673224
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [7.889902358829609]
# 	Value before the split: 14.97255288076138
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=225 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.98709578946433]
# 	Value before the split: 11.33176990105393
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=225 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [4.904434144305056]
# 	Value before the split: 9.120967273891612
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.338715536706326]
# 	Value before the split: 7.8543433962238725
#
# 	best_feature='feature-2'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': True, 'feature-2': False} and {'feature-1': True, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.000380843385777]
# 	Value before the split: 11.334547545650384
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.026163967520478]
# 	Value before the split: 11.388324896115849
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=255 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.946220225092253]
# 	Value before the split: 11.268695057738823
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=255 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.776549848544591]
# 	Value before the split: 11.342771064987305
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.887709988504879]
# 	Value before the split: 11.199297271273904
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [6.167712412102222]
# 	Value before the split: 11.292715419403304
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=285 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.88914002303208]
# 	Value before the split: 11.190994871558036
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=285 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.9612294832412775]
# 	Value before the split: 11.242258799427308
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=300 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.883569925361186]
# 	Value before the split: 11.178124473645868
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=300 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.917887984988505]
# 	Value before the split: 4.851175388569613
#
# 	best_feature='feature-2'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False, 'feature-2': False} and {'feature-1': False, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=315 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.893205446254646]
# 	Value before the split: 11.180641113581054
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=330 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.890418839676395]
# 	Value before the split: 11.171714540759874
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=345 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.854043594935558]
# 	Value before the split: 11.128469460211816
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=360 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.85131716012462]
# 	Value before the split: 11.119644000628288
#
# //////////////////////// exp#1 ////////////////////////
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.319753894449128, 12.636350475699492]
# 	Value before the split: 12.879688670210857
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.812538090520672, 9.680087136731814]
# 	Value before the split: 12.61886602217368
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=75 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [11.987920205436993, 12.139490720310203]
# 	Value before the split: 12.458798235093585
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=75 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.979705689345803, 9.90147843766841]
# 	Value before the split: 13.450911347907939
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.122787038906377, 12.245121230716883]
# 	Value before the split: 12.556368671709436
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.309780182431524, 10.382559403670857]
# 	Value before the split: 13.376328256580491
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=105 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.197432472905287, 12.402703228263587]
# 	Value before the split: 12.611691303456702
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=105 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.269502155458568, 9.384571922310705]
# 	Value before the split: 13.02202608061849
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.209914355226612, 12.455998461351092]
# 	Value before the split: 12.596234196133366
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.671129974475146, 10.114853412078613]
# 	Value before the split: 13.087553320694303
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=135 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.232999938433075, 12.70184854076809]
# 	Value before the split: 12.600277080760831
#
# 	best_feature='feature-1'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=135 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.285498251923643, 9.52222590628124]
# 	Value before the split: 12.96534247554251
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.042532530751913]
# 	Value before the split: 11.486662767106598
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.353079324396376]
# 	Value before the split: 14.953930542094476
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.201177226157188, 9.437749194862464]
# 	Value before the split: 12.941864428370017
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=165 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.88887772312558]
# 	Value before the split: 11.305592680147722
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.393923089424229]
# 	Value before the split: 14.806821796718108
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=165 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.217827390826322, 9.460240933766016]
# 	Value before the split: 10.531844228620681
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.848249567319696]
# 	Value before the split: 11.247509015791968
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.476829723481467]
# 	Value before the split: 14.912986353965938
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.664107319835214, 9.444836591535745]
# 	Value before the split: 12.845357105765393
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=195 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.91548066601176]
# 	Value before the split: 11.302546373225178
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.563668259613976]
# 	Value before the split: 15.041591383387486
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=195 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.909430994372563, 9.512076027570686]
# 	Value before the split: 12.857516080267738
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.885303830410956]
# 	Value before the split: 11.25586737176465
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.654441715225538]
# 	Value before the split: 15.176328551074372
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.919177422749318, 9.49204099095631]
# 	Value before the split: 12.804861751484088
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=225 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.795634117802269]
# 	Value before the split: 11.149042616679038
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.6414618665478]
# 	Value before the split: 15.145485406916746
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=225 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.90191154958023, 9.481876375250723]
# 	Value before the split: 12.824361459370166
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.725563643513134]
# 	Value before the split: 11.064413865872702
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.860566838738077]
# 	Value before the split: 15.36004971665347
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.498765429425426, 9.527750637989335]
# 	Value before the split: 12.820379137330319
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=255 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.696000059836315]
# 	Value before the split: 11.023073014733894
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.816318978795437]
# 	Value before the split: 15.303282076954199
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=255 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.517968374627676, 9.493982917444967]
# 	Value before the split: 12.857207542299339
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.729571686578584]
# 	Value before the split: 11.04736859108259
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.839713583956698]
# 	Value before the split: 15.312360051199748
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.522444933287408, 9.501684865574411]
# 	Value before the split: 12.237115945405533
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=285 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.688030651356469]
# 	Value before the split: 10.995739970082237
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.940916128907272]
# 	Value before the split: 15.40560386563797
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=285 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.0642671184017, 9.502420267030853]
# 	Value before the split: 12.771859252236387
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=300 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.666889051798009]
# 	Value before the split: 10.966511900940684
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.936813702985127]
# 	Value before the split: 15.388788370725027
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=300 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.469915934941469, 8.750883481470877]
# 	Value before the split: 12.723532756439624
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=315 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.710312927642189]
# 	Value before the split: 11.004219382858105
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.931962805013946]
# 	Value before the split: 15.370798641545687
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=315 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.462654419279021, 8.764903831776621]
# 	Value before the split: 12.731135782657095
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=330 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.678187736800822]
# 	Value before the split: 10.964924584563933
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.979116328339567]
# 	Value before the split: 15.410067758250964
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=330 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.4641555540629, 8.757511684451773]
# 	Value before the split: 12.74867870020224
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=345 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.666504127593065]
# 	Value before the split: 10.946005594154826
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.927328883234045]
# 	Value before the split: 15.346099230396781
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=345 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.467825371162915, 8.717659826283002]
# 	Value before the split: 12.752698999170603
# -------------------- RUNNING CONTEXT GENERATOR@t=360 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.677881492158424]
# 	Value before the split: 10.952176988396937
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.959361900050155]
# 	Value before the split: 15.370108876521915
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=360 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [8.471205536580804, 8.718537843487086]
# 	Value before the split: 12.748375296085484
#
# //////////////////////// exp#2 ////////////////////////
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.689456715836076, 12.76324370161446]
# 	Value before the split: 13.238336146480899
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=60 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [10.951857667886461, 10.34065589440851]
# 	Value before the split: 13.104327391176694
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=75 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.78076399087752, 12.731270445802252]
# 	Value before the split: 12.954248884163393
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=75 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [11.016456475196904, 10.327351074525861]
# 	Value before the split: 11.368765109745516
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.703502360742572, 12.725567215136234]
# 	Value before the split: 12.889439557879522
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=90 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.12303595187182, 8.96724643342517]
# 	Value before the split: 9.114934041245718
#
# 	best_feature='feature-2'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': False} and {'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=105 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.619353809532349, 12.707196188621918]
# 	Value before the split: 12.66690365853534
#
# 	best_feature='feature-1'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=105 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [6.351590393640386]
# 	Value before the split: 11.485646744765793
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [9.580830988252272]
# 	Value before the split: 14.678792759006242
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.957086312687808]
# 	Value before the split: 11.436592185782535
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.480374550081812]
# 	Value before the split: 15.209103500030983
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=120 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [6.373891128221002]
# 	Value before the split: 11.683224897735222
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [10.394477023890936]
# 	Value before the split: 15.088575076754323
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=135 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.97249686126952]
# 	Value before the split: 11.4231528024831
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.347785336618154]
# 	Value before the split: 15.015137397437224
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=135 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [6.7930957217326355]
# 	Value before the split: 11.358918541569787
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [10.215429058263279]
# 	Value before the split: 15.04162339911797
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.993496273315458]
# 	Value before the split: 11.42197365417076
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.39669230708753]
# 	Value before the split: 15.033272154120661
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [6.809327206446605]
# 	Value before the split: 9.274092525389518
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [10.182564760832134]
# 	Value before the split: 15.062128872125035
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=165 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.019307895954427]
# 	Value before the split: 11.429145944784489
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.424042603006548]
# 	Value before the split: 15.006630466199631
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=165 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [5.328655287874337]
# 	Value before the split: 11.176031016001039
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [10.52983736734355]
# 	Value before the split: 14.514299648564782
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.90547938028757]
# 	Value before the split: 11.29438700760716
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.464073662308234]
# 	Value before the split: 14.981707879100902
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [5.2682285875628905]
# 	Value before the split: 11.116373973231973
#
# - Evaluating the Node: feature_subspace={'feature-2': True} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [10.532522435047735]
# 	Value before the split: 7.123605252100202
#
# 	best_feature='feature-1'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-2': True, 'feature-1': False} and {'feature-2': True, 'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=195 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.941878649499765]
# 	Value before the split: 11.316909676830823
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.455384870236312]
# 	Value before the split: 15.003538330467398
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=195 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [4.633425495110077]
# 	Value before the split: 11.138074963909435
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.963859610982752]
# 	Value before the split: 11.326299069144756
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.354538319482648]
# 	Value before the split: 14.84365204352011
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [3.07087375527704]
# 	Value before the split: 11.12012915909917
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=225 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.914956728139217]
# 	Value before the split: 11.263722221046365
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.482537877919231]
# 	Value before the split: 14.899266330403139
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=225 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [5.057764058785514]
# 	Value before the split: 11.048203036276991
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.92262203986347]
# 	Value before the split: 11.25912036747823
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.455779877939108]
# 	Value before the split: 14.895226216366433
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [3.0666018260951304]
# 	Value before the split: 10.062850398628207
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=255 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.956985873197585]
# 	Value before the split: 11.284171036901359
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [14.523821176105642]
# 	Value before the split: 15.002975699039744
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=255 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-2': False} - is_leaf=True
#
# Features to check: ['feature-1']
# Analysis of the feature `feature-1`...
# 	Values after the split: [5.088657108431285]
# 	Value before the split: 7.0840927560164
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 --------------------
# N_LEAVES: 2
# ...
# Analysis of the feature `feature-2`...
# 	Values after the split: [6.219902852360284]
# 	Value before the split: 11.777185148765941
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.520944033785522]
# 	Value before the split: 15.64467738098277
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=135 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.804110224772508, 12.750123415613176]
# 	Value before the split: 12.940323376360471
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=135 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [6.16083728772381]
# 	Value before the split: 10.348583607335957
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.596010040174049]
# 	Value before the split: 13.281225471299068
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.9422705200367, 12.824735552713488]
# 	Value before the split: 12.958589145879861
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=150 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [6.2852614099621675]
# 	Value before the split: 11.800076164400807
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.542138319101298]
# 	Value before the split: 14.120967976108615
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=165 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.885745871735256, 12.769332131660025]
# 	Value before the split: 12.924011014407826
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=165 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.092300501725635]
# 	Value before the split: 11.642100530557292
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [9.97474220965018]
# 	Value before the split: 15.379606325689124
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.77421405123845, 12.76462351630304]
# 	Value before the split: 12.802309954891218
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=180 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [6.4013536354438365]
# 	Value before the split: 9.400338098039065
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [9.658084104192259]
# 	Value before the split: 15.327383376411989
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=195 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.761073558062089, 12.743507326086876]
# 	Value before the split: 12.83966085029174
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=195 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.6681041946213675]
# 	Value before the split: 11.466073557314628
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [9.730093532934418]
# 	Value before the split: 15.242630339781298
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.776145860263412, 12.791297655606439]
# 	Value before the split: 12.839840124208758
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=210 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.677228939920622]
# 	Value before the split: 11.454665172257371
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.440577792692455]
# 	Value before the split: 15.000791331185555
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=225 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.75132167959493, 12.77366021854699]
# 	Value before the split: 12.805804724536806
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=225 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.68514880222053]
# 	Value before the split: 11.374218176488482
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.552006232268019]
# 	Value before the split: 14.645699305480909
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.771714745460045, 12.766820504613829]
# 	Value before the split: 12.80831567864849
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=240 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.693674614559134]
# 	Value before the split: 11.347801233865212
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.598752296860821]
# 	Value before the split: 14.716082431228898
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=255 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.74940860905781, 12.7604853056109]
# 	Value before the split: 12.779860719632131
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=255 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.69857877861191]
# 	Value before the split: 11.32542410426532
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.658788190156907]
# 	Value before the split: 14.857276584091224
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.690700304286217, 12.70490181885614]
# 	Value before the split: 12.733205076669242
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=270 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.70738948851448]
# 	Value before the split: 10.02185986837006
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [9.74450076941342]
# 	Value before the split: 14.639163403812987
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=285 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.724069014895605, 12.735470566209143]
# 	Value before the split: 12.744304723302937
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=285 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.713950228930873]
# 	Value before the split: 11.218446816412516
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.63724104050005]
# 	Value before the split: 14.748830837627759
# -------------------- RUNNING CONTEXT GENERATOR@t=300 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={} - is_leaf=True
#
# Features to check: ['feature-2', 'feature-1']
# Analysis of the feature `feature-2`...
# Analysis of the feature `feature-1`...
# 	Values after the split: [12.762777219592824, 12.77880659175326]
# 	Value before the split: 12.75865293857952
#
# 	best_feature='feature-1'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': False} and {'feature-1': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=300 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.71478594146018]
# 	Value before the split: 11.296323396133262
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.974636230368557]
# 	Value before the split: 14.66212593821338
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=315 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.138152045778352]
# 	Value before the split: 11.440869922770231
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [15.277561307717175]
# 	Value before the split: 15.313188291609489
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=315 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.720337133160971]
# 	Value before the split: 11.341774628931262
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [10.944606555034557]
# 	Value before the split: 14.193489666414642
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=330 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.148865786160677]
# 	Value before the split: 11.443777069151183
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [15.3494701250647]
# 	Value before the split: 15.34879604892298
#
# 	best_feature='feature-2'
# NEW CONTEXT GENERATED:
#  splitting into -> {'feature-1': True, 'feature-2': False} and {'feature-1': True, 'feature-2': True}
#
# -------------------- RUNNING CONTEXT GENERATOR@t=330 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.720432292870986]
# 	Value before the split: 11.31556168987809
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.049561827625547]
# 	Value before the split: 14.687243439939726
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=345 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.151200511498942]
# 	Value before the split: 11.438347914211963
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=345 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.408908646565514]
# 	Value before the split: 10.234015995555282
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.047212337470842]
# 	Value before the split: 14.812040849200704
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=360 --------------------
# N_LEAVES: 1
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.147909428777709]
# 	Value before the split: 11.428612160382901
#
#
# -------------------- RUNNING CONTEXT GENERATOR@t=360 --------------------
# N_LEAVES: 2
# - Evaluating the Node: feature_subspace={'feature-1': False} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [5.420859583606909]
# 	Value before the split: 9.746078514329474
#
# - Evaluating the Node: feature_subspace={'feature-1': True} - is_leaf=True
#
# Features to check: ['feature-2']
# Analysis of the feature `feature-2`...
# 	Values after the split: [11.118511027753202]
# 	Value before the split: 14.774424103681488

# %%
plt.figure()
plt.ylabel("num_splits")
plt.xlabel("experiment")
for val in context_split_experiment.values():
    plt.plot(val, '--o')
plt.legend(context_split_experiment.keys())
plt.show()

# %%
for key in context_split_experiment:
    print(f'{key}: avg splits -> {np.mean(context_split_experiment[key])}')
# Out:
# TS-Pricing: avg splits -> 2.1
# UCB-Pricing: avg splits -> 1.7

# %%
# Plotting the results
plt.figure(figsize=(10,8))
plt.ylabel("Regret")
plt.xlabel("day")
opt = global_opt * fixed_clicks
for val in rewards_per_experiment.values():
    plt.plot(np.cumsum(np.mean(opt - val, axis=0)))
plt.legend(rewards_per_experiment.keys())
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.xlabel("day")
plt.ylabel("daily reward")
plt.plot([opt]*365, '--g', label='clairwoyant')
for key in rewards_per_experiment:
    plt.plot(np.mean(rewards_per_experiment[key], axis=0), label=key)
plt.legend(loc='best')
plt.show()
