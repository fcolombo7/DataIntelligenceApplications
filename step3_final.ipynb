# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

from data_generators.basic_generator import BasicDataGenerator

from utils.tasks.task3 import Task3

# %%
data_generator = BasicDataGenerator(filename='src/basic001.json')
task = Task3(data_generator)

# %% [markdown]
# ### WRONG BECAUSE THE SRC DATA IS CHANGED

# %%
task.load('simulations_results/result_step3_delay.zip')
# Out:
# Simulation's result loaded from `simulations_results/result_step3_delay.zip`.

# %%
task.plot(0, theme='whitegrid')

# %%
task.plot(1, theme='whitegrid')

# %% [markdown]
# ---
# After refactoring the code...

# %%
new_task = Task3(data_generator)

# %%
new_task.load('simulations_results/result_REFACTOR-3.zip')
# Out:
# Simulation's result loaded from `simulations_results/result_REFACTOR-3.zip`.

# %%
new_task.plot(0, theme='whitegrid')

# %%
new_task.plot(1, theme='whitegrid')
